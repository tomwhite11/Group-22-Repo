# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_pickle("2022-07_tweet_data_anti_vax.pkl")
x = df['tweet_id']
y = df['negative_tweet_sentiment']

# Horizontal Bar Plot
plt.bar(x, y)

plt.gca().axes.get_xaxis().set_visible(False)
# Show Plot
plt.show()

# %%
df = pd.read_pickle("2022-07_tweet_data_deep_state.pkl")
x = df['tweet_id']
y = df['negative_tweet_sentiment']

# Horizontal Bar Plot
plt.bar(x, y)

plt.gca().axes.get_xaxis().set_visible(False)
# Show Plot
plt.show()

# %%
df = pd.read_pickle("2022-07_tweet_data_combined.pkl")
x = df['tweet_id']
y = df['negative_tweet_sentiment']

# Horizontal Bar Plot
plt.bar(x, y)

plt.gca().axes.get_xaxis().set_visible(False)
# Show Plot
plt.show()

# %%
CountDf=pd.read_pickle("2022-07_tweet_count_deep_state.pkl")
x= CountDf["date"]
y= CountDf["count"]

plt.plot(x,y)

plt.gca().axes.get_xaxis().set_visible(False)

plt.show()
