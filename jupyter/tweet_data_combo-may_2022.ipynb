# %%
import os
import json
from pprint import pprint
import pandas as pd

# %%
JSON_FILES= []

#JSON_FILES.append(os.path.join(data_path, "2022-05-01.json/2022-05-01.json")
#JSON_FILES.append("C:/Users/user/OneDrive - Cardiff University/en/en/2022-05-02.json/2022-05-02.json")
#JSON_FILES.append("C:/Users/user/OneDrive - Cardiff University/en/en/2022-05-03.json/2022-05-03.json")
#JSON_FILES.append("C:/Users/user/OneDrive - Cardiff University/en/en/2022-05-04.json/2022-05-04.json")
#JSON_FILES.append("C:/Users/user/OneDrive - Cardiff University/en/en/2022-05-05.json/2022-05-05.json")
#JSON_FILES.append("C:/Users/user/OneDrive - Cardiff University/en/en/2022-05-06.json/2022-05-06.json")
#JSON_FILES.append("C:/Users/user/OneDrive - Cardiff University/en/en/2022-05-07.json/2022-05-07.json")
#JSON_FILES.append("C:/Users/user/OneDrive - Cardiff University/en/en/2022-05-08.json/2022-05-08.json")
#JSON_FILES.append("C:/Users/user/OneDrive - Cardiff University/en/en/2022-05-09.json/2022-05-09.json")
#JSON_FILES.append("C:/Users/user/OneDrive - Cardiff University/en/en/2022-05-10.json/2022-05-10.json")
#JSON_FILES.append("C:/Users/user/OneDrive - Cardiff University/en/en/2022-05-11.json/2022-05-11.json")
#JSON_FILES.append("C:/Users/user/OneDrive - Cardiff University/en/en/2022-05-12.json/2022-05-12.json")
#JSON_FILES.append("C:/Users/user/OneDrive - Cardiff University/en/en/2022-05-13.json/2022-05-13.json")
#JSON_FILES.append("C:/Users/user/OneDrive - Cardiff University/en/en/2022-05-14.json/2022-05-14.json")
#JSON_FILES.append("C:/Users/user/OneDrive - Cardiff University/en/en/2022-05-15.json/2022-05-15.json")
#JSON_FILES.append("C:/Users/user/OneDrive - Cardiff University/en/en/2022-05-16.json/2022-05-16.json")
#JSON_FILES.append("C:/Users/user/OneDrive - Cardiff University/en/en/2022-05-17.json/2022-05-17.json")
#JSON_FILES.append("C:/Users/user/OneDrive - Cardiff University/en/en/2022-05-18.json/2022-05-18.json")
#JSON_FILES.append("C:/Users/user/OneDrive - Cardiff University/en/en/2022-05-19.json/2022-05-19.json")
#JSON_FILES.append("C:/Users/user/OneDrive - Cardiff University/en/en/2022-05-20.json/2022-05-20.json")
#JSON_FILES.append("C:/Users/user/OneDrive - Cardiff University/en/en/2022-05-21.json/2022-05-21.json")
#JSON_FILES.append("C:/Users/user/OneDrive - Cardiff University/en/en/2022-05-22.json/2022-05-22.json")
#JSON_FILES.append("C:/Users/user/OneDrive - Cardiff University/en/en/2022-05-23.json/2022-05-23.json")
#JSON_FILES.append("C:/Users/user/OneDrive - Cardiff University/en/en/2022-05-24.json/2022-05-24.json")
#JSON_FILES.append("C:/Users/user/OneDrive - Cardiff University/en/en/2022-05-25.json/2022-05-25.json")
#JSON_FILES.append("C:/Users/user/OneDrive - Cardiff University/en/en/2022-05-26.json/2022-05-26.json")
#JSON_FILES.append("C:/Users/user/OneDrive - Cardiff University/en/en/2022-05-27.json/2022-05-27.json")
#JSON_FILES.append("C:/Users/user/OneDrive - Cardiff University/en/en/2022-05-28.json/2022-05-28.json")
#JSON_FILES.append("C:/Users/user/OneDrive - Cardiff University/en/en/2022-05-29.json/2022-05-29.json")
#JSON_FILES.append("C:/Users/user/OneDrive - Cardiff University/en/en/2022-05-30.json/2022-05-30.json")
# JSON_FILES.append("C:/Users/user/OneDrive - Cardiff University/en/en/2022-05-31.json/2022-05-31.json")

JSON_FILES.append("../2022-07-27.json")

# %%
with open(JSON_FILES[0], "r") as f:
    line = f.readline()
    data = json.loads(line)
    pprint(data)
# Out:
# {'_id': {'$oid': '62e1d18b703be440a0f7933c'},
#  'collected_by': 'sentinelRibTwitter',
#  'contributors': None,
#  'coordinates': None,
#  'created_at': {'$date': 1658966399000},
#  'created_at_src': 'Wed Jul 27 23:59:59 +0000 2022',
#  'entities': {'emotion': [],
#               'hashtags': [],
#               'indexed_by': {},
#               'ner': [],
#               'ontology': [],
#               'pronoun': [],
#               'swearword': [],
#               'symbols': [],
#               'token': [],
#               'urls': [{'display_url': 'eldesconcierto.cl/nacional/2022/…',
#                         'expanded_url': 'https://www.eldesconcierto.cl/nacional/2022/07/27/video-por-favor-no-desinformes-carol-bown-lanza-feroz-fake-news-y-es-corregida-al-aire.html?utm_term=Autofeed&utm_medium=Social&utm_source=Twitter#Echobox=1658956332',
#                         'indices': [111, 134],
#                         'url': 'https://t.co/Z8PFE7Em8F'}],
# ...

# %%
rows=[]
CountDict=[]
for JSON_FILE in JSON_FILES:
    with open(JSON_FILE, "r") as f:
        count=0
        for line in f:
            data = json.loads(line)

            screen_name = data["user"]["screen_name"]
            tweet_id = data["id_str"]
            reply_count = data["reply_count"]
            quote_count = data["quote_count"]
            retweet_count = data["retweet_count"]
            like_count = data["favorite_count"]
            if "sentiment" in data["entities"]:
                Negative_tweet_sentiment=data["entities"]["sentiment"]["probabilities"]["Very negative"]+data["entities"]["sentiment"]["probabilities"]["Negative"]
                Positive_tweet_sentiment=data["entities"]["sentiment"]["probabilities"]["Very positive"]+data["entities"]["sentiment"]["probabilities"]["Positive"]
            else:
                Negative_tweet_sentiment = None;
                Positive_tweet_sentiment = None;

            if "extended_tweet" in data:
                text = data["extended_tweet"]["full_text"]
            else:
                text = data["text"]

            if ("deep state" and "interference") and "antivax" in text:
                interact_count = like_count+retweet_count+quote_count+reply_count
                rows.append((tweet_id, screen_name, text, Negative_tweet_sentiment, Positive_tweet_sentiment, reply_count, quote_count, retweet_count, like_count,  interact_count))
                count=count+1
        CountDict.append([JSON_FILE[68:76],count])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 7
#       5 count=0
#       6 for line in f:
# ----> 7     data = json.loads(line)
#       9     screen_name = data["user"]["screen_name"]
#      10     tweet_id = data["id_str"]
#
# File /usr/lib/python3.10/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File /usr/lib/python3.10/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
# ...

# %%
df = pd.DataFrame(data=rows, columns=["tweet_id", "screen_name", "tweet_text","negative_tweet_sentiment","positive_tweet_sentiment","reply_count","quote_count","retweet_count","like_count","interact_count"])
CountDf = pd.DataFrame(data=CountDict, columns=["date", "count"])
print(CountDf)

# %%
df.head(5)
df = df.dropna()
CountDf = CountDf.dropna()
CountDf['date'] = pd.to_datetime(CountDf['date'])

# %%
df.to_pickle("2022-05_tweet_data_combined.pkl")
CountDf.to_pickle("2022-05_tweet_count_combined.pkl")

# %%
df.head(20)
