# %%
# Python imports
import os, sys
dir2 = os.path.abspath('')
dir1 = os.path.dirname(dir2)
if not dir1 in sys.path: sys.path.append(dir1)

# Local imports
from lib.plot_functions import *
from lib.filepaths import *

dataset = path.join(DATA_PATH, '2022-07_tweet_data_deep_state.pkl')

# %%
bar_chart(dataset, 'tweet_id', 'negative_tweet_sentiment')

# %%
# word_cloud(dataset, 'tweet_text')
word_cloud(dataset, 'tweet_text', filters=['@', 'http', 'https', 'RT', 'rt', 'RT:'])

# %%
# Apply the get_sentiment function to all tweet texts in the dataset
sentiment_analysis(dataset, 'tweet_text')
